# %%
library("tidyverse")
# Out:
# ── Attaching core tidyverse packages ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.0     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.2.0
# ── Conflicts ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
library("xgboost")
# Out:
# Error in library("xgboost"): there is no package called ‘xgboost’
# Traceback:
#
# 1. stop(packageNotFoundError(package, lib.loc, sys.call()))

# %%
pkgs <- c(
  # base data / plotting
  "tidyverse", "pryr", "plyr",
  "gridExtra", "cowplot", "hexbin", "ggtext", "ggpubr", "ggdendro",
  "GGally", "see", "patchwork", "cobalt",
  "ggseqlogo", "pheatmap", "UpSetR", "plotly",
  "boot", "coin", "zoo", "psych", "corrr", "kableExtra",
  "simpleCache", "devtools", "R.utils", "pak",
  "fastcluster", "FactoMineR", "factoextra",
  # graph tools
  "igraph", "tidygraph", "ggraph",
  # tree-based modeling & SHAP
  "xgboost", "SHAPforxgboost", "iml", "fastshap",
  # IRkernel
  "IRkernel",
  # Bioconductor-ish (you installed via BiocManager)
  "IRanges", "GenomicRanges", "rtracklayer",
  "AnnotationHub", "ExperimentHub",
  "GenomicDistributions", "GenomicDistributionsData"
)

cat("=== R package check ===\n")
for (p in pkgs) {
  if (requireNamespace(p, quietly = TRUE)) {
    ver <- tryCatch(as.character(utils::packageVersion(p)),
                    error = function(e) "version ?")
    cat(sprintf("%-25s OK   version: %s\n", p, ver))
  } else {
    cat(sprintf("%-25s MISSING\n", p))
  }
}
# Out:
# === R package check ===
# tidyverse                 OK   version: 2.0.0
# pryr                      OK   version: 0.1.6
# plyr                      OK   version: 1.8.9
# gridExtra                 OK   version: 2.3
# cowplot                   OK   version: 1.2.0
# hexbin                    OK   version: 1.28.5
# ggtext                    OK   version: 0.1.2
# ggpubr                    OK   version: 0.6.2
# ggdendro                  OK   version: 0.2.0
# GGally                    OK   version: 2.4.0
# see                       OK   version: 0.12.0
# patchwork                 OK   version: 1.3.2
# cobalt                    OK   version: 4.6.1
# ggseqlogo                 OK   version: 0.2
# pheatmap                  OK   version: 1.0.13
# UpSetR                    OK   version: 1.4.0
# plotly                    OK   version: 4.11.0
# boot                      OK   version: 1.3.32
# coin                      OK   version: 1.4.3
# zoo                       OK   version: 1.8.14
# ...
