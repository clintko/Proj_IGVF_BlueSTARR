# %% [raw]
# ---
# title: Variant results from Richard 01
# subtitle: Explore and get the files
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
source ../run_config_project.sh
show_env
# Out:
# BASE DIRECTORY (FD_BASE):      /hpc/group/igvf/kk319
# REPO DIRECTORY (FD_REPO):      /hpc/group/igvf/kk319/repo
# WORK DIRECTORY (FD_WORK):      /hpc/group/igvf/kk319/work
# DATA DIRECTORY (FD_DATA):      /hpc/group/igvf/kk319/data
# CONTAINER DIR. (FD_SING):      /hpc/group/igvf/kk319/container
#
# You are working with
# PATH OF PROJECT (FD_PRJ):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR
# PROJECT RESULTS (FD_RES):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results
# PROJECT SCRIPTS (FD_EXE):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/scripts
# PROJECT DATA    (FD_DAT):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/data
# PROJECT NOTE    (FD_NBK):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/notebooks
# PROJECT DOCS    (FD_DOC):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/docs
# PROJECT LOG     (FD_LOG):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/log
# PROJECT REF     (FD_REF):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/references
# PROJECT IMAGE   (FP_PRJ_SIF):  /hpc/group/igvf/kk319/container/project/singularity_proj_igvf_bluestarr.sif
# PROJECT CONF.   (FP_CNF):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/scripts/config_project.sh
# PROJECT APP     (FP_APP):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/scripts/run_script.sh

# %% [markdown]
# ## Preview

# %%
ls -1 ${FD_RES}
# Out:
# analysis_variant_delta_alphagenome
# analysis_variant_motif_richard
# predict_variant_alphagenome
# predict_variant_kircher2019

# %%
ls ${FD_RES}/analysis_variant_motif_richard
# Out:
# background_zero_order.npy
# background_zero_order.tsv
# batches_dev
# batches_full
# batches_pilot
# JASPAR2024_CORE_vertebrates_non-redundant.lods.npz
# JASPAR2024_CORE_vertebrates_non-redundant.lods.pkl
# JASPAR2024_CORE_vertebrates_non-redundant.pmap.npz
# JASPAR2024_CORE_vertebrates_non-redundant.pmap.pkl
# motifdelta_pilot_jaspar2024
# motifdelta_pilot_jvierstra_v2.0beta
# motif_jaspar2024_core_vertebrates_nonredundant.lods.pkl
# motif_jaspar2024_core_vertebrates_nonredundant.pmap.pkl
# motif_nonredundant_jvierstra_v2.0beta.lods.pkl
# motif_nonredundant_jvierstra_v2.0beta.pmap.pkl
# tmp
# variant_closed_gof_bluestarr_flank35_obs.fa
# variant_closed_gof_bluestarr_flank35_ref.fa
# variant_closed_gof_bluestarr_flank35_unobs.fa
# variant_closed_gof_bluestarr_flankL35R70_obs.fa
# variant_closed_gof_bluestarr_flankL35R70_ref.fa
# variant_closed_gof_bluestarr_flankL35R70_unobs.fa
# variant_closed_gof_bluestarr.tsv.gz
# variant_closed_gof_bluestarr_withseq_flank35.tsv.gz
# variant_closed_gof_bluestarr_withseq_flankL35R70.tsv.gz

# %%
ls ${FD_RES}/analysis_variant_motif_richard/motifdelta_pilot_jaspar2024 | head -n 10
# Out:
# variant_closed_gof_bluestarr_flankL35R70_pilot_chunk001_delta.npz
# variant_closed_gof_bluestarr_flankL35R70_pilot_chunk001_event.tsv
# variant_closed_gof_bluestarr_flankL35R70_pilot_chunk001_scan.npz
# variant_closed_gof_bluestarr_flankL35R70_pilot_chunk001_summary_motif.tsv
# variant_closed_gof_bluestarr_flankL35R70_pilot_chunk001_summary_variant.tsv
# variant_closed_gof_bluestarr_flankL35R70_pilot_chunk002_delta.npz
# variant_closed_gof_bluestarr_flankL35R70_pilot_chunk002_event.tsv
# variant_closed_gof_bluestarr_flankL35R70_pilot_chunk002_scan.npz
# variant_closed_gof_bluestarr_flankL35R70_pilot_chunk002_summary_motif.tsv
# variant_closed_gof_bluestarr_flankL35R70_pilot_chunk002_summary_variant.tsv

# %%
ls ${FD_RES}/analysis_variant_motif_richard/motifdelta_pilot_jvierstra_v2.0beta | head -n 10
# Out:
# variant_closed_gof_bluestarr_flankL35R70_pilot_chunk001_delta.npz
# variant_closed_gof_bluestarr_flankL35R70_pilot_chunk001_event.tsv
# variant_closed_gof_bluestarr_flankL35R70_pilot_chunk001_scan.npz
# variant_closed_gof_bluestarr_flankL35R70_pilot_chunk001_summary_motif.tsv
# variant_closed_gof_bluestarr_flankL35R70_pilot_chunk001_summary_variant.tsv
# variant_closed_gof_bluestarr_flankL35R70_pilot_chunk002_delta.npz
# variant_closed_gof_bluestarr_flankL35R70_pilot_chunk002_event.tsv
# variant_closed_gof_bluestarr_flankL35R70_pilot_chunk002_scan.npz
# variant_closed_gof_bluestarr_flankL35R70_pilot_chunk002_summary_motif.tsv
# variant_closed_gof_bluestarr_flankL35R70_pilot_chunk002_summary_variant.tsv

# %% [markdown]
# ## Execute

# %% [markdown]
# ### Jaspar2024

# %%
FD_BATCH=${FD_RES}/analysis_variant_motif_richard/batches_pilot
FP_MOTIF=${FD_RES}/analysis_variant_motif_richard/motif_jaspar2024_core_vertebrates_nonredundant.lods.pkl
FP_MODEL=${FD_RES}/analysis_variant_motif_richard/motif_jaspar2024_core_vertebrates_nonredundant.pmap.pkl
FD_DELTA=${FD_RES}/analysis_variant_motif_richard/motifdelta_pilot_jaspar2024
PREFIX=${FD_DELTA}/variant_closed_gof_bluestarr_flankL35R70_pilot

# %%
### set resource
NUM_CPU=2
NUM_MEM=4G

### execute
FP_EXE=${FD_EXE}/run_motifdelta_03_merge.py
FN_LOG=run_motifdelta_merge_batch_pilot_jaspar.txt
FP_LOG=${FD_LOG}/${FN_LOG}
echo '${FD_LOG}'/"${FN_LOG}"
    
sbatch \
    -A majoroslab \
    -p igvf \
    --cpus-per-task ${NUM_CPU} \
    --mem    ${NUM_MEM} \
    --output ${FP_LOG} \
    --chdir  ${FD_EXE} \
    ${FP_APP} python ${FP_EXE} \
        --txt_fpath_dir ${FD_DELTA} \
        --txt_fpath_output_prefix ${PREFIX} \
        --num_top_events_global 1000
# Out:
# ${FD_LOG}/run_motifdelta_merge_batch_pilot_jaspar.txt
# Submitted batch job 40272323

# %% [markdown]
# ### jvierstra non-redundant motif

# %%
FD_BATCH=${FD_RES}/analysis_variant_motif_richard/batches_pilot
FP_MOTIF=${FD_RES}/analysis_variant_motif_richard/motif_nonredundant_jvierstra_v2.0beta.lods.pkl
FP_MODEL=${FD_RES}/analysis_variant_motif_richard/motif_nonredundant_jvierstra_v2.0beta.pmap.pkl
FD_DELTA=${FD_RES}/analysis_variant_motif_richard/motifdelta_pilot_jvierstra_v2.0beta
PREFIX=${FD_DELTA}/variant_closed_gof_bluestarr_flankL35R70_pilot

# %%
### set resource
NUM_CPU=2
NUM_MEM=4G

### execute
FP_EXE=${FD_EXE}/run_motifdelta_03_merge.py
FN_LOG=run_motifdelta_merge_batch_pilot_jvierstra.txt
FP_LOG=${FD_LOG}/${FN_LOG}
echo '${FD_LOG}'/"${FN_LOG}"
    
sbatch \
    -A majoroslab \
    -p igvf \
    --cpus-per-task ${NUM_CPU} \
    --mem    ${NUM_MEM} \
    --output ${FP_LOG} \
    --chdir  ${FD_EXE} \
    ${FP_APP} python ${FP_EXE} \
        --txt_fpath_dir ${FD_DELTA} \
        --txt_fpath_output_prefix ${PREFIX} \
        --num_top_events_global 1000
# Out:
# ${FD_LOG}/run_motifdelta_merge_batch_pilot_jvierstra.txt
# Submitted batch job 40272324

# %% [markdown]
# ## Review

# %%
cat ${FD_LOG}/run_motifdelta_merge_batch_pilot_jaspar.txt
# Out:
# Found 20 motif summary files.
# Found 20 variant summary files.
# Found 20 event files.
# Import all tables in 0.00 seconds
#
# Merging motif-level summaries...
# Merging variant-level summaries...
# Merging event tables into global tables...
# Merge tables in 4.07 seconds
#
# Saving merged motif summary to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot_jaspar2024/variant_closed_gof_bluestarr_flankL35R70_pilot_summary_motif_merged.tsv
# Saving merged variant summary to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot_jaspar2024/variant_closed_gof_bluestarr_flankL35R70_pilot_summary_variant_merged.tsv
# Saving all events to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot_jaspar2024/variant_closed_gof_bluestarr_flankL35R70_pilot_events_all.tsv
# Saving top gain events to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot_jaspar2024/variant_closed_gof_bluestarr_flankL35R70_pilot_events_top_gain.tsv
# Saving top loss events to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot_jaspar2024/variant_closed_gof_bluestarr_flankL35R70_pilot_events_top_loss.tsv
# Save outputs in 8.09 seconds
#
# Done.

# %%
sacct_summary.sh 40272323
# Out:
# ===== Summary (.ba tasks) =====
# JobID                               JobName      State    Elapsed   TotalCPU     MaxRSS
# ------------ ------------------------------ ---------- ---------- ---------- ----------
# 40272323.ba+                          batch  COMPLETED   00:00:14  00:12.748   1153500K
#
# ===== ElapsedRaw =====
# ElapsedRaw = 14 sec (0.23 min)
#
# ===== MaxRSS =====
# MaxRSS = 1.10 GiB

# %%
cat ${FD_LOG}/run_motifdelta_merge_batch_pilot_jvierstra.txt
# Out:
# Found 20 motif summary files.
# Found 20 variant summary files.
# Found 20 event files.
# Import all tables in 0.01 seconds
#
# Merging motif-level summaries...
# Merging variant-level summaries...
# Merging event tables into global tables...
# Merge tables in 5.13 seconds
#
# Saving merged motif summary to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot_jvierstra_v2.0beta/variant_closed_gof_bluestarr_flankL35R70_pilot_summary_motif_merged.tsv
# Saving merged variant summary to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot_jvierstra_v2.0beta/variant_closed_gof_bluestarr_flankL35R70_pilot_summary_variant_merged.tsv
# Saving all events to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot_jvierstra_v2.0beta/variant_closed_gof_bluestarr_flankL35R70_pilot_events_all.tsv
# Saving top gain events to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot_jvierstra_v2.0beta/variant_closed_gof_bluestarr_flankL35R70_pilot_events_top_gain.tsv
# Saving top loss events to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot_jvierstra_v2.0beta/variant_closed_gof_bluestarr_flankL35R70_pilot_events_top_loss.tsv
# Save outputs in 10.54 seconds
#
# Done.

# %%
sacct_summary.sh 40272324
# Out:
# ===== Summary (.ba tasks) =====
# JobID                               JobName      State    Elapsed   TotalCPU     MaxRSS
# ------------ ------------------------------ ---------- ---------- ---------- ----------
# 40272324.ba+                          batch  COMPLETED   00:00:17  00:16.332   1322068K
#
# ===== ElapsedRaw =====
# ElapsedRaw = 17 sec (0.28 min)
#
# ===== MaxRSS =====
# MaxRSS = 1.26 GiB

# %% [markdown]
# ## Execute

# %%
FD_BATCH=${FD_RES}/analysis_variant_motif_richard/batches_pilot
FP_MOTIF=${FD_RES}/analysis_variant_motif_richard/JASPAR2024_CORE_vertebrates_non-redundant.lods.pkl
FP_MODEL=${FD_RES}/analysis_variant_motif_richard/JASPAR2024_CORE_vertebrates_non-redundant.pmap.pkl
FD_DELTA=${FD_RES}/analysis_variant_motif_richard/motifdelta_pilot

PREFIX=${FD_DELTA}/variant_closed_gof_bluestarr_flankL35R70_pilot

# %%
### set resource
NUM_CPU=2
NUM_MEM=4G

### execute
FP_EXE=${FD_EXE}/run_motifdelta_03_merge.py
FP_LOG=${FD_LOG}/run_motifdelta_merge_batch_pilot.txt
echo '${FD_LOG}'/"run_motifdelta_merge_batch_pilot.txt"
    
sbatch \
    -A majoroslab \
    -p igvf \
    --cpus-per-task ${NUM_CPU} \
    --mem    ${NUM_MEM} \
    --output ${FP_LOG} \
    --chdir  ${FD_EXE} \
    ${FP_APP} python ${FP_EXE} \
        --txt_fpath_dir ${FD_DELTA} \
        --txt_fpath_output_prefix ${PREFIX} \
        --num_top_events_global 1000
# Out:
# ${FD_LOG}/run_motifdelta_merge_batch_pilot.txt
# Submitted batch job 40167614

# %% [markdown]
# ## Preview

# %%
JobID=40167614
sacct -j ${JobID} --format=JobID,JobName%30,State,Elapsed,TotalCPU,MaxRSS
sacct -j ${JobID} --format=JobID,MaxRSS \
| grep '\.ba' \
| awk '
{
    raw = $2
    unit = substr(raw, length(raw), 1)
    gsub(/[^0-9]/, "", raw)
    val = raw + 0        # numeric value

    # Convert to GiB
    if (unit == "K") {
        gib = val / 1024 / 1024      # K -> GiB
    } else if (unit == "M") {
        gib = val / 1024             # MiB -> GiB
    } else if (unit == "G") {
        gib = val                    # already GiB (ish)
    } else {
        # fallback: assume K if no unit
        gib = val / 1024 / 1024
    }
}
END {
    printf "memory=%.2f GiB\n", 
            gib
}'
# Out:
# JobID                               JobName      State    Elapsed   TotalCPU     MaxRSS
# ------------ ------------------------------ ---------- ---------- ---------- ----------
# 40167614                      run_script.sh  COMPLETED   00:00:14  00:12.522
# 40167614.ba+                          batch  COMPLETED   00:00:14  00:12.520   1141844K
# 40167614.ex+                         extern  COMPLETED   00:00:14  00:00.001          0
# memory=1.09 GiB

# %%
cat ${FD_LOG}/run_motifdelta_merge_batch_pilot.txt
# Out:
# Found 20 motif summary files.
# Found 20 variant summary files.
# Found 20 event files.
# Import all tables in 0.02 seconds
#
# Merging motif-level summaries...
# Merging variant-level summaries...
# Merging event tables into global tables...
# Merge tables in 4.21 seconds
#
# Saving merged motif summary to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot/variant_closed_gof_bluestarr_flankL35R70_pilot_summary_motif_merged.tsv
# Saving merged variant summary to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot/variant_closed_gof_bluestarr_flankL35R70_pilot_summary_variant_merged.tsv
# Saving all events to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot/variant_closed_gof_bluestarr_flankL35R70_pilot_events_all.tsv
# Saving top gain events to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot/variant_closed_gof_bluestarr_flankL35R70_pilot_events_top_gain.tsv
# Saving top loss events to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot/variant_closed_gof_bluestarr_flankL35R70_pilot_events_top_loss.tsv
# Save outputs in 7.90 seconds
#
# Done.
