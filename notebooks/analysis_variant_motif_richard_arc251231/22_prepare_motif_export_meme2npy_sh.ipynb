# %% [raw]
# ---
# title: Variant results from Richard 01
# subtitle: Explore and get the files
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
source ../run_config_project.sh
show_env
# Out:
# BASE DIRECTORY (FD_BASE):      /hpc/group/igvf/kk319
# REPO DIRECTORY (FD_REPO):      /hpc/group/igvf/kk319/repo
# WORK DIRECTORY (FD_WORK):      /hpc/group/igvf/kk319/work
# DATA DIRECTORY (FD_DATA):      /hpc/group/igvf/kk319/data
# CONTAINER DIR. (FD_SING):      /hpc/group/igvf/kk319/container
#
# You are working with
# PATH OF PROJECT (FD_PRJ):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR
# PROJECT RESULTS (FD_RES):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results
# PROJECT SCRIPTS (FD_EXE):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/scripts
# PROJECT DATA    (FD_DAT):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/data
# PROJECT NOTE    (FD_NBK):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/notebooks
# PROJECT DOCS    (FD_DOC):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/docs
# PROJECT LOG     (FD_LOG):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/log
# PROJECT REF     (FD_REF):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/references
# PROJECT IMAGE   (FP_PRJ_SIF):  /hpc/group/igvf/kk319/container/project/singularity_proj_igvf_bluestarr.sif
# PROJECT CONF.   (FP_CNF):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/scripts/config_project.sh
# PROJECT APP     (FP_APP):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/scripts/run_script.sh

# %% [markdown]
# ## Explore motif

# %% [markdown]
# ### Jaspar2024

# %% [markdown]
# ```
# MEME version 4
#
# ALPHABET= ACGT
#
# Background letter frequencies
# A 0.25 C 0.25 G 0.25 T 0.25
# ```

# %%
ls ${FD_DATA}/jaspar2024
# Out:
# JASPAR2024_CORE_non-redundant_pfms_jaspar.zip
# JASPAR2024_CORE_non-redundant_pfms_meme.zip
# JASPAR2024_CORE_non-redundant_pfms_transfac.zip
# JASPAR2024_CORE_vertebrates_meme
# JASPAR2024_CORE_vertebrates_non-redundant.meme
# JASPAR2024_CORE_vertebrates_non-redundant.npz
# JASPAR2024_CORE_vertebrates_non-redundant_pfms_jaspar.zip
# JASPAR2024_CORE_vertebrates_non-redundant_pfms_meme.zip
# JASPAR2024_CORE_vertebrates_non-redundant_pfms_transfac.zip

# %%
TXT_FDIRY=${FD_DATA}/jaspar2024
TXT_FNAME="JASPAR2024_CORE_vertebrates_non-redundant.meme"
TXT_FPATH=${TXT_FDIRY}/${TXT_FNAME}

cat ${TXT_FPATH} | head -n 22
# Out:
# MEME version 4
#
# ALPHABET= ACGT
#
# strands: + -
#
# Background letter frequencies
# A 0.25 C 0.25 G 0.25 T 0.25
#
# MOTIF MA0002.3 Runx1
# letter-probability matrix: alength= 4 w= 9 nsites= 2000 E= 0
#  0.061500  0.536000  0.074500  0.328000
#  0.028500  0.000000  0.003500  0.968000
#  0.000000  0.037500  0.936000  0.026500
#  0.043500  0.063500  0.035000  0.858000
#  0.000000  0.000000  0.993500  0.006500
#  0.008500  0.021000  0.924000  0.046500
#  0.005000  0.200000  0.125500  0.669500
#  0.065500  0.231500  0.040500  0.662500
#  0.250000  0.079000  0.144500  0.526500
# URL http://jaspar.genereg.net/matrix/MA0002.3

# %% [markdown]
# ### Non-redundant motifs

# %%
ls ${FD_DATA}/nonredundant_motif_jvierstra_v2.0beta
# Out:
# all.dbs.meme  consensus_pwms.meme

# %%
TXT_FDIRY=${FD_DATA}/nonredundant_motif_jvierstra_v2.0beta
TXT_FNAME="consensus_pwms.meme"
TXT_FPATH=${TXT_FDIRY}/${TXT_FNAME}

cat ${TXT_FPATH} | head -n 22
# Out:
# MEME version 4
#
# ALPHABET= ACGT
#
# strands: + -
#
# Background letter frequencies (from uniform background):
# A 0.25000 C 0.25000 G 0.25000 T 0.25000
#
# MOTIF AC0001:DLX/LHX:Homeodomain AC0001:DLX/LHX:Homeodomain
#
# letter-probability matrix: alength= 4 w= 6 nsites= 20 E= 0
#   0.014812	  0.085107	  0.008622	  0.891459
#   0.868196	  0.081842	  0.037794	  0.012168
#   0.990919	  0.002737	  0.003995	  0.002349
#   0.002690	  0.003078	  0.007087	  0.987145
#   0.012626	  0.048229	  0.096419	  0.842726
#   0.638595	  0.010997	  0.330025	  0.020383
#
# MOTIF AC0002:EMX/PAX:Homeodomain AC0002:EMX/PAX:Homeodomain
#
# letter-probability matrix: alength= 4 w= 12 nsites= 20 E= 0

# %% [markdown]
# ## Execute: Export motif to numpy array

# %% [markdown]
# ### JASPAR 2024

# %%
TXT_FDIRY_INP="/hpc/group/igvf/kk319/data/jaspar2024"
TXT_FNAME_INP="JASPAR2024_CORE_vertebrates_non-redundant.meme"
TXT_FPATH_INP=${TXT_FDIRY_INP}/${TXT_FNAME_INP}

TXT_FDIRY_OUT="/hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard"
TXT_FNAME_BKG="background_zero_order.npy"
TXT_FPATH_BKG=${TXT_FDIRY_OUT}/${TXT_FNAME_BKG}

#TXT_FNAME_OUT="JASPAR2024_CORE_vertebrates_non-redundant.lods.pkl"
TXT_FNAME_OUT="motif_jaspar2024_core_vertebrates_nonredundant.lods.pkl"
TXT_FPATH_OUT=${TXT_FDIRY_OUT}/${TXT_FNAME_OUT}

# %%
### set script
FP_EXE=${FD_EXE}/run_motif_meme2lods.py

### set log file
FP_LOG=${FD_LOG}/run_motif_meme2lods_jaspar2024.txt

### set resource
NUM_CPU=2
NUM_MEM=4G

### execute
sbatch \
    -A majoroslab \
    -p igvf \
    --cpus-per-task ${NUM_CPU} \
    --mem    ${NUM_MEM} \
    --output ${FP_LOG}  \
    --chdir  ${FD_EXE}  \
    run_memelite python ${FP_EXE} \
        --txt_fpath_inp ${TXT_FPATH_INP} \
        --txt_fpath_bgk ${TXT_FPATH_BKG} \
        --txt_fpath_out ${TXT_FPATH_OUT}
# Out:
# Submitted batch job 40235153

# %% [markdown]
# ### Non-redundant motifs

# %%
TXT_FDIRY_INP="/hpc/group/igvf/kk319/data/nonredundant_motif_jvierstra_v2.0beta"
TXT_FNAME_INP="consensus_pwms.meme"
TXT_FPATH_INP=${TXT_FDIRY_INP}/${TXT_FNAME_INP}

TXT_FDIRY_OUT="/hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard"
TXT_FNAME_BKG="background_zero_order.npy"
TXT_FPATH_BKG=${TXT_FDIRY_OUT}/${TXT_FNAME_BKG}

TXT_FNAME_OUT="motif_nonredundant_jvierstra_v2.0beta.lods.pkl"
TXT_FPATH_OUT=${TXT_FDIRY_OUT}/${TXT_FNAME_OUT}

# %%
### set script
FP_EXE=${FD_EXE}/run_motif_meme2lods.py

### set log file
FP_LOG=${FD_LOG}/run_motif_meme2lods_jvierstra.txt

### set resource
NUM_CPU=2
NUM_MEM=4G

### execute
sbatch \
    -A majoroslab \
    -p igvf \
    --cpus-per-task ${NUM_CPU} \
    --mem    ${NUM_MEM} \
    --output ${FP_LOG}  \
    --chdir  ${FD_EXE}  \
    run_memelite python ${FP_EXE} \
        --txt_fpath_inp ${TXT_FPATH_INP} \
        --txt_fpath_bgk ${TXT_FPATH_BKG} \
        --txt_fpath_out ${TXT_FPATH_OUT}
# Out:
# Submitted batch job 40235175

# %% [markdown]
# ## Review

# %%
cat ${FD_LOG}/run_motif_meme2lods_jaspar2024.txt
# Out:
# Loaded background: [0.31068281 0.18781458 0.18880759 0.31269502]
# Loaded 879 motifs from MEME file
# Saved 879 motifs -> /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/JASPAR2024_CORE_vertebrates_non-redundant.lods.pkl

# %%
sacct_summary.sh 40235153
# Out:
# ===== Summary (.ba tasks) =====
# JobID                               JobName      State    Elapsed   TotalCPU     MaxRSS
# ------------ ------------------------------ ---------- ---------- ---------- ----------
# 40235153.ba+                          batch  COMPLETED   00:00:05  00:04.135    260824K
#
# ===== ElapsedRaw =====
# ElapsedRaw = 5 sec (0.08 min)
#
# ===== MaxRSS =====
# MaxRSS = 0.25 GiB

# %%
cat ${FD_LOG}/run_motif_meme2lods_jvierstra.txt
# Out:
# Loaded background: [0.31068281 0.18781458 0.18880759 0.31269502]
# Loaded 693 motifs from MEME file
# Saved 693 motifs -> /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motif_nonredundant_jvierstra_v2.0beta.lods.pkl

# %%
sacct_summary.sh 40235175
# Out:
# ===== Summary (.ba tasks) =====
# JobID                               JobName      State    Elapsed   TotalCPU     MaxRSS
# ------------ ------------------------------ ---------- ---------- ---------- ----------
# 40235175.ba+                          batch  COMPLETED   00:00:04  00:04.856    258316K
#
# ===== ElapsedRaw =====
# ElapsedRaw = 4 sec (0.07 min)
#
# ===== MaxRSS =====
# MaxRSS = 0.25 GiB
