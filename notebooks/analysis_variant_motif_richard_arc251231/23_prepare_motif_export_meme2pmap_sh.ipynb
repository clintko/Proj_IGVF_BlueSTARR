# %% [raw]
# ---
# title: Variant results from Richard 01
# subtitle: Explore and get the files
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
source ../run_config_project.sh
show_env
# Out:
# BASE DIRECTORY (FD_BASE):      /hpc/group/igvf/kk319
# REPO DIRECTORY (FD_REPO):      /hpc/group/igvf/kk319/repo
# WORK DIRECTORY (FD_WORK):      /hpc/group/igvf/kk319/work
# DATA DIRECTORY (FD_DATA):      /hpc/group/igvf/kk319/data
# CONTAINER DIR. (FD_SING):      /hpc/group/igvf/kk319/container
#
# You are working with
# PATH OF PROJECT (FD_PRJ):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR
# PROJECT RESULTS (FD_RES):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results
# PROJECT SCRIPTS (FD_EXE):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/scripts
# PROJECT DATA    (FD_DAT):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/data
# PROJECT NOTE    (FD_NBK):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/notebooks
# PROJECT DOCS    (FD_DOC):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/docs
# PROJECT LOG     (FD_LOG):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/log
# ...

# %% [markdown]
# ## Execute

# %% [markdown]
# ### Jaspar 2024

# %%
TXT_FDIRY_INP="/hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard"
TXT_FNAME_INP="motif_jaspar2024_core_vertebrates_nonredundant.lods.pkl"
TXT_FPATH_INP=${TXT_FDIRY_INP}/${TXT_FNAME_INP}

TXT_FDIRY_OUT=${TXT_FDIRY_INP}
TXT_FNAME_OUT="motif_jaspar2024_core_vertebrates_nonredundant.pmap.pkl"
TXT_FPATH_OUT=${TXT_FDIRY_OUT}/${TXT_FNAME_OUT}

# %%
### set script
FP_EXE=${FD_EXE}/run_motif_lods2pmap.py

### set log file
FP_LOG=${FD_LOG}/run_motif_meme2pmap_jaspar2024.txt

### set resource
NUM_CPU=10
NUM_MEM=10G

### execute
sbatch \
    -A majoroslab \
    -p igvf \
    --cpus-per-task ${NUM_CPU} \
    --mem    ${NUM_MEM} \
    --output ${FP_LOG}  \
    --chdir  ${FD_EXE}  \
    ${FP_APP} python ${FP_EXE} \
        --txt_fpath_inp ${TXT_FPATH_INP} \
        --txt_fpath_out ${TXT_FPATH_OUT} \
        --num_workers 10
# Out:
# Submitted batch job 40270888

# %% [markdown]
# ### Non-redundant motifs

# %%
TXT_FDIRY_INP="/hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard"
TXT_FNAME_INP="motif_nonredundant_jvierstra_v2.0beta.lods.pkl"
TXT_FPATH_INP=${TXT_FDIRY_INP}/${TXT_FNAME_INP}

TXT_FDIRY_OUT=${TXT_FDIRY_INP}
TXT_FNAME_OUT="motif_nonredundant_jvierstra_v2.0beta.pmap.pkl"
TXT_FPATH_OUT=${TXT_FDIRY_OUT}/${TXT_FNAME_OUT}

# %%
### set script
FP_EXE=${FD_EXE}/run_motif_lods2pmap.py

### set log file
FP_LOG=${FD_LOG}/run_motif_meme2pmap_jvierstra.txt

### set resource
NUM_CPU=10
NUM_MEM=10G

### execute
sbatch \
    -A majoroslab \
    -p igvf \
    --cpus-per-task ${NUM_CPU} \
    --mem    ${NUM_MEM} \
    --output ${FP_LOG}  \
    --chdir  ${FD_EXE}  \
    ${FP_APP} python ${FP_EXE} \
        --txt_fpath_inp ${TXT_FPATH_INP} \
        --txt_fpath_out ${TXT_FPATH_OUT} \
        --num_workers 10
# Out:
# Submitted batch job 40270889

# %% [markdown]
# ## Review

# %% [markdown]
# It loaded 879 motifs from JASPAR2024. The empirical background was read successfully. Progress logs show parallel precomputation ran across all motifs. It completed all motifs and saved the file:
# `/hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/
# JASPAR2024_CORE_vertebrates_non-redundant.pmap.npz`

# %% [markdown]
# The job used 10 CPUs, ran for ~10 seconds, and used 2~4 GB RAM total

# %%
cat ${FD_LOG}/run_motif_meme2pmap_jaspar2024.txt
# Out:
# Loaded /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motif_jaspar2024_core_vertebrates_nonredundant.lods.pkl
# Loaded 879 motifs
# Loaded background: [0.31068281 0.18781458 0.18880759 0.31269502]
# [100/879] MA0143.5 SOX2
# [200/879] MA0601.2 Arid3b
# [300/879] MA0702.3 LMX1A
# [400/879] MA0802.2 TBR1
# [500/879] MA0903.2 HOXB3
# [600/879] MA1498.3 HOXA7
# [700/879] MA1615.2 Plagl1
# [800/879] MA1963.2 SATB1
# [879/879] MA2341.1 FEZF2
# Finished precomputing p-maps for 879 motifs.
# Saved DP-maps for 879 motifs -> /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motif_jaspar2024_core_vertebrates_nonredundant.pmap.pkl

# %%
sacct_summary.sh 40270888
# Out:
# ===== Summary (.ba tasks) =====
# JobID                               JobName      State    Elapsed   TotalCPU     MaxRSS
# ------------ ------------------------------ ---------- ---------- ---------- ----------
# 40270888.ba+                          batch  COMPLETED   00:00:09  00:15.712   3403912K
#
# ===== ElapsedRaw =====
# ElapsedRaw = 9 sec (0.15 min)
#
# ===== MaxRSS =====
# MaxRSS = 3.25 GiB

# %%
cat ${FD_LOG}/run_motif_meme2pmap_jvierstra.txt
# Out:
# Loaded /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motif_nonredundant_jvierstra_v2.0beta.lods.pkl
# Loaded 693 motifs
# Loaded background: [0.31068281 0.18781458 0.18880759 0.31269502]
# [100/693] AC0100:POU2F:Homeodomain,POU AC0100:POU2F:Homeodomain,POU
# [200/693] AC0201:ZNF:C2H2_ZF AC0201:ZNF:C2H2_ZF
# [300/693] AC0300:ZNF:C2H2_ZF AC0300:ZNF:C2H2_ZF
# [400/693] AC0400:ZNF:C2H2_ZF AC0400:ZNF:C2H2_ZF
# [500/693] AC0499:TFAP2A/TFAP2C:AP-2 AC0499:TFAP2A/TFAP2C:AP-2
# [600/693] AC0600:ZNF:C2H2_ZF AC0600:ZNF:C2H2_ZF
# [693/693] AC0693:IKZF/NFKB:Rel AC0693:IKZF/NFKB:Rel
# Finished precomputing p-maps for 693 motifs.
# Saved DP-maps for 693 motifs -> /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motif_nonredundant_jvierstra_v2.0beta.pmap.pkl

# %%
sacct_summary.sh 40270889
# Out:
# ===== Summary (.ba tasks) =====
# JobID                               JobName      State    Elapsed   TotalCPU     MaxRSS
# ------------ ------------------------------ ---------- ---------- ---------- ----------
# 40270889.ba+                          batch  COMPLETED   00:00:07  00:14.367   2701088K
#
# ===== ElapsedRaw =====
# ElapsedRaw = 7 sec (0.12 min)
#
# ===== MaxRSS =====
# MaxRSS = 2.58 GiB

# %% [markdown]
# ## Review

# %% [markdown]
# ```
# 38954825      igvf run_scri    kk319  R       0:42      1 dcc-allenlab-01
# 38982355      igvf run_scri    kk319  R       0:35      1 dcc-allenlab-01
# ```

# %%
sacct -j 39547174 --format=JobID,JobName,Partition,AllocCPUs,State,Elapsed,MaxRSS,MaxVMSize
# Out:
# JobID           JobName  Partition  AllocCPUS      State    Elapsed     MaxRSS  MaxVMSize
# ------------ ---------- ---------- ---------- ---------- ---------- ---------- ----------
# 39547174     run_scrip+       igvf         10  COMPLETED   00:00:11
# 39547174.ba+      batch                    10  COMPLETED   00:00:11   3404860K          0
# 39547174.ex+     extern                    10  COMPLETED   00:00:11       256K          0

# %%
echo ${FP_LOG} 
echo
cat  ${FP_LOG}
# Out:
# /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/log/run_motif_lods2pmap.txt
#
# Loaded /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/JASPAR2024_CORE_vertebrates_non-redundant.lods.pkl
# Loaded 879 motifs
# Loaded background: [0.31068281 0.18781458 0.18880759 0.31269502]
# [0/879] MA0004.1 Arnt
# [100/879] MA0142.1 Pou5f1::Sox2
# [200/879] MA0601.2 Arid3b
# [300/879] MA0703.3 LMX1B
# [400/879] MA0802.2 TBR1
# [500/879] MA0904.3 HOXB5
# [600/879] MA1499.2 HOXB4
# [700/879] MA1616.2 Prdm15
# [800/879] MA1962.1 POU2F1::SOX2
# [878/879] MA2341.1 FEZF2
# Finished precomputing p-maps for 879 motifs.
# Saved DP-maps for 879 motifs -> /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/JASPAR2024_CORE_vertebrates_non-redundant.pmap.pkl
