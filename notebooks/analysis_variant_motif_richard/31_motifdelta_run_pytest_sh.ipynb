# %% [raw]
# ---
# title: Variant results from Richard 01
# subtitle: Explore and get the files
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
source ../run_config_project.sh
show_env
# Out:
# BASE DIRECTORY (FD_BASE):      /hpc/group/igvf/kk319
# REPO DIRECTORY (FD_REPO):      /hpc/group/igvf/kk319/repo
# WORK DIRECTORY (FD_WORK):      /hpc/group/igvf/kk319/work
# DATA DIRECTORY (FD_DATA):      /hpc/group/igvf/kk319/data
# CONTAINER DIR. (FD_SING):      /hpc/group/igvf/kk319/container
#
# You are working with
# PATH OF PROJECT (FD_PRJ):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR
# PROJECT RESULTS (FD_RES):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results
# PROJECT SCRIPTS (FD_EXE):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/scripts
# PROJECT DATA    (FD_DAT):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/data
# PROJECT NOTE    (FD_NBK):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/notebooks
# PROJECT DOCS    (FD_DOC):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/docs
# PROJECT LOG     (FD_LOG):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/log
# ...

# %% [markdown]
# ## Prepare

# %% [markdown]
# ### Check packacage folder structure

# %%
ls ${FD_EXE}/motifdelta
echo
ls ${FD_EXE}/motifdelta/src
echo
ls ${FD_EXE}/motifdelta/src/motifdelta
echo
ls ${FD_EXE}/motifdelta/src/motifdelta/stats
echo
ls ${FD_EXE}/motifdelta/src/motifdelta/seq
echo
ls ${FD_EXE}/motifdelta/src/motifdelta/score
echo
ls ${FD_EXE}/motifdelta/tests
# Out:
# LICENSE  pyproject.toml  README.md  src  tests
#
# motifdelta  motifdelta.egg-info
#
# __init__.py  __pycache__  score  seq  stats
#
# background.py  __init__.py  pvalue.py  __pycache__
#
# encode_arc260113.py  __init__.py  rc_arc260113.py
# encode.py            __pycache__  rc.py
#
# __init__.py  lod.py  __pycache__  scan.py
#
# __pycache__  test_background.py  test_encode.py  test_rc.py  test_scan.py

# %% [markdown]
# ### Check import inside container

# %%
"${FP_APP}" python -c "import motifdelta, sys; print('motifdelta=', motifdelta); print('file=', getattr(motifdelta,'__file__',None)); print('path=', list(getattr(motifdelta,'__path__', []))); print('sys.path[0:10]=', sys.path[0:10])"
# Out:
# motifdelta= <module 'motifdelta' from '/hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/scripts/motifdelta/src/motifdelta/__init__.py'>
# file= /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/scripts/motifdelta/src/motifdelta/__init__.py
# path= ['/hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/scripts/motifdelta/src/motifdelta']
# sys.path[0:10]= ['', '/hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/scripts/motifdelta/src', '/hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/scripts', '/hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/notebooks/analysis_variant_motif_richard', '/opt/conda/lib/python311.zip', '/opt/conda/lib/python3.11', '/opt/conda/lib/python3.11/lib-dynload', '/opt/conda/lib/python3.11/site-packages']

# %% [markdown]
# ## Run tests

# %%
FD_TEST=${FD_EXE}/motifdelta/tests

# %% [markdown]
# ### Test Background

# %%
"${FP_APP}" python -c "from motifdelta.stats import background_zero_order; print(background_zero_order)"
"${FP_APP}" python -c "from motifdelta.stats import *; print([k for k in globals().keys() if 'background' in k])"
# Out:
# <function background_zero_order at 0x7fcccf2e9d00>
# ['background_zero_order']

# %%
"${FP_APP}" python -m motifdelta.stats.background --help
# Out:
# <frozen runpy>:128: RuntimeWarning: 'motifdelta.stats.background' found in sys.modules after import of package 'motifdelta.stats', but prior to execution of 'motifdelta.stats.background'; this may result in unpredictable behaviour

# %%
${FP_APP} python -m pytest -v ${FD_TEST}/test_background.py
# Out:
# ]9;4;3;\============================= test session starts ==============================
# platform linux -- Python 3.11.6, pytest-9.0.1, pluggy-1.6.0 -- /opt/conda/bin/python
# cachedir: .pytest_cache
# rootdir: /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/scripts/motifdelta
# configfile: pyproject.toml
# plugins: anyio-4.0.0, jaxtyping-0.3.3, typeguard-4.4.4, zarr-3.1.5
# collected 2 items
#
# ../../scripts/motifdelta/tests/test_background.py::test_background_case01_uniform ]9;4;1;0\PASSED [ 50%]
# ../../scripts/motifdelta/tests/test_background.py::test_background_case02_at_rich ]9;4;1;50\PASSED [100%]]9;4;0;\
#
# ============================== 2 passed in 0.10s ===============================

# %% [markdown]
# ### Test ENCODE

# %%
${FP_APP} python -m pytest -v ${FD_TEST}/test_encode.py
# Out:
# ]9;4;3;\============================= test session starts ==============================
# platform linux -- Python 3.11.6, pytest-9.0.1, pluggy-1.6.0 -- /opt/conda/bin/python
# cachedir: .pytest_cache
# rootdir: /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/scripts/motifdelta
# configfile: pyproject.toml
# plugins: anyio-4.0.0, jaxtyping-0.3.3, typeguard-4.4.4, zarr-3.1.5
# collected 3 items
#
# ../../scripts/motifdelta/tests/test_encode.py::test_one_hot_case01_encode ]9;4;1;0\PASSED [ 33%]
# ../../scripts/motifdelta/tests/test_encode.py::test_one_hot_case02_decode ]9;4;1;33\PASSED [ 66%]
# ../../scripts/motifdelta/tests/test_encode.py::test_one_hot_case03_unknown_bases ]9;4;1;66\PASSED [100%]]9;4;0;\
#
# ============================== 3 passed in 0.05s ===============================

# %% [markdown]
# ### Test RC

# %%
${FP_APP} python -m pytest -v ${FD_TEST}/test_rc.py
# Out:
# ]9;4;3;\============================= test session starts ==============================
# platform linux -- Python 3.11.6, pytest-9.0.1, pluggy-1.6.0 -- /opt/conda/bin/python
# cachedir: .pytest_cache
# rootdir: /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/scripts/motifdelta
# configfile: pyproject.toml
# plugins: anyio-4.0.0, jaxtyping-0.3.3, typeguard-4.4.4, zarr-3.1.5
# collected 5 items
#
# ../../scripts/motifdelta/tests/test_rc.py::test_reverse_complement_sequence_basic ]9;4;1;0\PASSED [ 20%]
# ../../scripts/motifdelta/tests/test_rc.py::test_reverse_complement_sequence_case_insensitive ]9;4;1;20\PASSED [ 40%]
# ../../scripts/motifdelta/tests/test_rc.py::test_reverse_complement_matrix_matches_string ]9;4;1;40\PASSED [ 60%]
# ../../scripts/motifdelta/tests/test_rc.py::test_reverse_complement_matrix_shape ]9;4;1;60\PASSED [ 80%]
# ../../scripts/motifdelta/tests/test_rc.py::test_reverse_complement_matrix_double_rc_is_identity ]9;4;1;80\PASSED [100%]]9;4;0;\
#
# ...

# %% [markdown]
# ### Test SCAN

# %%
${FP_APP} python -m pytest -v ${FD_TEST}/test_scan.py
# Out:
# ]9;4;3;\============================= test session starts ==============================
# platform linux -- Python 3.11.6, pytest-9.0.1, pluggy-1.6.0 -- /opt/conda/bin/python
# cachedir: .pytest_cache
# rootdir: /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/scripts/motifdelta
# configfile: pyproject.toml
# plugins: anyio-4.0.0, jaxtyping-0.3.3, typeguard-4.4.4, zarr-3.1.5
# collected 6 items
#
# ../../scripts/motifdelta/tests/test_scan.py::test_scan_basic_shape_and_finite ]9;4;1;0\PASSED [ 16%]
# ../../scripts/motifdelta/tests/test_scan.py::test_scan_perfect_match_single_window ]9;4;1;16\PASSED [ 33%]
# ../../scripts/motifdelta/tests/test_scan.py::test_scan_single_mismatch ]9;4;1;33\PASSED [ 50%]
# ../../scripts/motifdelta/tests/test_scan.py::test_scan_multiple_windows_values ]9;4;1;50\PASSED [ 66%]
# ../../scripts/motifdelta/tests/test_scan.py::test_rc_consistency_forward_equals_rc_scanned_reversed ]9;4;1;66\PASSED [ 83%]
# ...
