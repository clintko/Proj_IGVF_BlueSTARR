# %% [raw]
# ---
# title: Variant results from Richard 01
# subtitle: Explore and get the files
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
source ../run_config_project.sh
show_env
# Out:
# BASE DIRECTORY (FD_BASE):      /hpc/group/igvf/kk319
# REPO DIRECTORY (FD_REPO):      /hpc/group/igvf/kk319/repo
# WORK DIRECTORY (FD_WORK):      /hpc/group/igvf/kk319/work
# DATA DIRECTORY (FD_DATA):      /hpc/group/igvf/kk319/data
# CONTAINER DIR. (FD_SING):      /hpc/group/igvf/kk319/container
#
# You are working with
# PATH OF PROJECT (FD_PRJ):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR
# PROJECT RESULTS (FD_RES):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results
# PROJECT SCRIPTS (FD_EXE):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/scripts
# PROJECT DATA    (FD_DAT):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/data
# PROJECT NOTE    (FD_NBK):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/notebooks
# PROJECT DOCS    (FD_DOC):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/docs
# PROJECT LOG     (FD_LOG):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/log
# PROJECT REF     (FD_REF):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/references
# PROJECT IMAGE   (FP_PRJ_SIF):  /hpc/group/igvf/kk319/container/project/singularity_proj_igvf_bluestarr.sif
# PROJECT CONF.   (FP_CNF):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/scripts/config_project.sh
# PROJECT APP     (FP_APP):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/scripts/run_script.sh

# %% [markdown]
# ## Preview

# %%
ls -1 ${FD_RES}
# Out:
# analysis_variant_motif_richard
# analysis_variant_motif_richard_arc251231
# analysis_variant_motif_richard_arc260223
# predict_variant_alphagenome
# predict_variant_kircher2019

# %%
ls ${FD_RES}/analysis_variant_motif_richard
# Out:
# background_zero_order.npy
# background_zero_order.tsv
# batches_dev
# batches_pilot_low_dinuc
# batches_pilot_low_ori
# batches_pilot_top_dinuc
# batches_pilot_top_ori
# batches_top_dinuc
# batches_top_ori
# motifdelta_pilot_low_dinuc_jvierstra_v2.1beta
# motifdelta_pilot_low_ori_jvierstra_v2.1beta
# motifdelta_pilot_top_dinuc_jvierstra_v2.1beta
# motifdelta_pilot_top_ori_jvierstra_v2.1beta
# motifdelta_top_ori_jaspar2024
# motifdelta_top_ori_jvierstra_v2.1beta
# motif_jaspar2024_core_vertebrates_nonredundant.lods.pkl
# motif_jaspar2024_core_vertebrates_nonredundant.pmap.pkl
# motif_jaspar2024_core_vertebrates_nonredundant.tbind.pkl
# motif_nonredundant_jvierstra_v2.1beta.lods.pkl
# motif_nonredundant_jvierstra_v2.1beta.pmap.pkl
# motif_nonredundant_jvierstra_v2.1beta.tbind.pkl
# motifscan_pilot_low_dinuc_jvierstra_v2.1beta
# motifscan_pilot_low_ori_jvierstra_v2.1beta
# motifscan_pilot_top_dinuc_jvierstra_v2.1beta
# motifscan_pilot_top_ori_jvierstra_v2.1beta
# motifscan_top_ori_jaspar2024
# motifscan_top_ori_jvierstra_v2.1beta
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.ref.fa
# variant_closed_gof_bluestarr.tsv

# %% [markdown]
# **Set compute resource**

# %%
### choose compute profile
CHOOSE_PARTITION="biostat"
#CHOOSE_PARTITION="igvf"
#CHOOSE_PARTITION="igvf_common"
#CHOOSE_PARTITION="biostat_common"

case "$CHOOSE_PARTITION" in
    igvf)
        SLURM_ACCOUNT="majoroslab"
        SLURM_PARTITION="igvf"
        ;;
    igvf_common)
        SLURM_ACCOUNT="majoroslab"
        SLURM_PARTITION="igvf,common"
        ;;
    biostat)
        SLURM_ACCOUNT="biostat"
        SLURM_PARTITION="biostat"
        ;;
    biostat_common)
        SLURM_ACCOUNT="biostat"
        SLURM_PARTITION="biostat,common"
        ;;
    *)
        echo "Unknown CHOOSE_PARTITION: $CHOOSE_PARTITION" >&2
        exit 1
        ;;
esac

### optional: node excludes (ONLY if needed)
EXCLUDE_COMMON="dcc-comp-10,dcc-core-08,dcc-core-53"
EXCLUDE_NODES=""

# Check if "common" is one of the comma-separated partitions
if [[ ",${SLURM_PARTITION}," == *",common,"* ]]; then
  EXCLUDE_NODES="${EXCLUDE_COMMON}"
fi

echo "SLURM_ACCOUNT=${SLURM_ACCOUNT}"
echo "SLURM_PARTITION=${SLURM_PARTITION}"
echo "EXCLUDE_NODES=${EXCLUDE_NODES:-<none>}"
# Out:
# SLURM_ACCOUNT=biostat
# SLURM_PARTITION=biostat
# EXCLUDE_NODES=<none>

# %% [markdown]
# ## Non-redundant motifs

# %% [markdown]
# ### Prepare

# %%
ls -1 ${FD_RES}/analysis_variant_motif_richard/motifscan_pilot_top_ori_jvierstra_v2.1beta
echo
ls -1 ${FD_RES}/analysis_variant_motif_richard/motifscan_pilot_low_ori_jvierstra_v2.1beta
echo
ls -1 ${FD_RES}/analysis_variant_motif_richard/motifscan_pilot_top_dinuc_jvierstra_v2.1beta
echo
ls -1 ${FD_RES}/analysis_variant_motif_richard/motifscan_pilot_low_dinuc_jvierstra_v2.1beta
# Out:
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk001.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk002.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk003.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk004.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk005.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk006.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk007.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk008.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk009.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk010.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk011.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk012.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk013.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk014.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk015.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk016.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk017.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk018.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk019.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk020.npz
#
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk001.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk002.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk003.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk004.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk005.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk006.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk007.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk008.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk009.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk010.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk011.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk012.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk013.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk014.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk015.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk016.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk017.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk018.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk019.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk020.npz
#
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk001.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk002.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk003.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk004.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk005.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk006.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk007.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk008.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk009.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk010.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk011.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk012.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk013.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk014.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk015.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk016.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk017.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk018.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk019.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk020.npz
#
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk001.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk002.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk003.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk004.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk005.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk006.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk007.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk008.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk009.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk010.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk011.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk012.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk013.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk014.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk015.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk016.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk017.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk018.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk019.npz
# variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk020.npz

# %% [markdown]
# ### Execute

# %%
### set script
FP_EXE=${FD_EXE}/run_motifdelta_02_delta.sh

### set slurm opt
NUM_CPU=2
NUM_MEM=20G
LST_OPTS=(
    -A "${SLURM_ACCOUNT}"
    -p "${SLURM_PARTITION}"
    --cpus-per-task="${NUM_CPU}"
    --mem="${NUM_MEM}"
    --chdir="${FD_EXE}"
    --export=ALL,FP_CNF="${FP_CNF}"
    --parsable
)

if [[ -n "${EXCLUDE_NODES}" ]]; then
  LST_OPTS+=( --exclude="${EXCLUDE_NODES}" )
fi

### set parameters
FN_PREFIX="variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs"
FP_MOTIF=${FD_RES}/analysis_variant_motif_richard/motif_nonredundant_jvierstra_v2.1beta.lods.pkl
FP_TBIND=${FD_RES}/analysis_variant_motif_richard/motif_nonredundant_jvierstra_v2.1beta.tbind.pkl
TXT_MOTIF_SET=jvierstra_v2.1beta
TXT_MOTIF_LAB=jvierstra

### Loop init
TXT_EXE=motifdelta
LST_BATCH_SET=(pilot_top pilot_low)
LST_SRC=(ori dinuc)
LST_JOBS=()

### Loop through I/O
for TXT_BATCH_SET in "${LST_BATCH_SET[@]}"; do
    for TXT_SRC in "${LST_SRC[@]}"; do
    
        ### Set input/output batch directory based on batch set
        TXT_FOLDER="${TXT_BATCH_SET}_${TXT_SRC}"
        FD_BATCH=${FD_RES}/analysis_variant_motif_richard/batches_${TXT_FOLDER}
        FD_MSCAN=${FD_RES}/analysis_variant_motif_richard/motifscan_${TXT_FOLDER}_${TXT_MOTIF_SET}
        FD_DELTA=${FD_RES}/analysis_variant_motif_richard/motifdelta_${TXT_FOLDER}_${TXT_MOTIF_SET}

        for i in $(seq -w 001 020); do
            ### set job/log
            TXT_TAG="${TXT_BATCH_SET}_chunk${i}"
            TXT_JOB="${TXT_EXE}.${TXT_MOTIF_LAB}.${TXT_FOLDER}.${TXT_TAG}"    
            FN_LOG="run.${TXT_JOB}.txt"
            FP_LOG=${FD_LOG}/${FN_LOG}
            
            ### set I/O
            FP_INP=${FD_MSCAN}/${FN_PREFIX}.${TXT_TAG}.npz
            FP_OUT_PREFIX=${FD_DELTA}/${FN_PREFIX}.${TXT_TAG}
            
            ### check file existence
            if [[ ! -f "${FP_INP}" ]]; then
                echo "Missing input: ${FP_INP}"
                continue
            fi
            
            ### execute
            JOBID=$(sbatch   \
                "${LST_OPTS[@]}" \
                --job-name="${TXT_JOB}" \
                --output="${FP_LOG}"    \
                "${FP_EXE}" "${FP_INP}" "${FP_TBIND}" "${FP_OUT_PREFIX}" \
                | tr -cd '0-9'
            )
            echo "Submitted ${TXT_TAG}: ${JOBID}"
            echo "LOG: \${FD_LOG}/${FN_LOG}"
            LST_JOBS+=("${JOBID}")
        done
        echo
    done
done
# Out:
# Submitted pilot_top_chunk001: 43779855
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_ori.pilot_top_chunk001.txt
# Submitted pilot_top_chunk002: 43779856
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_ori.pilot_top_chunk002.txt
# Submitted pilot_top_chunk003: 43779857
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_ori.pilot_top_chunk003.txt
# Submitted pilot_top_chunk004: 43779858
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_ori.pilot_top_chunk004.txt
# Submitted pilot_top_chunk005: 43779859
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_ori.pilot_top_chunk005.txt
# Submitted pilot_top_chunk006: 43779860
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_ori.pilot_top_chunk006.txt
# Submitted pilot_top_chunk007: 43779861
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_ori.pilot_top_chunk007.txt
# Submitted pilot_top_chunk008: 43779862
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_ori.pilot_top_chunk008.txt
# Submitted pilot_top_chunk009: 43779863
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_ori.pilot_top_chunk009.txt
# Submitted pilot_top_chunk010: 43779864
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_ori.pilot_top_chunk010.txt
# Submitted pilot_top_chunk011: 43779865
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_ori.pilot_top_chunk011.txt
# Submitted pilot_top_chunk012: 43779866
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_ori.pilot_top_chunk012.txt
# Submitted pilot_top_chunk013: 43779867
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_ori.pilot_top_chunk013.txt
# Submitted pilot_top_chunk014: 43779868
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_ori.pilot_top_chunk014.txt
# Submitted pilot_top_chunk015: 43779869
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_ori.pilot_top_chunk015.txt
# Submitted pilot_top_chunk016: 43779870
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_ori.pilot_top_chunk016.txt
# Submitted pilot_top_chunk017: 43779871
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_ori.pilot_top_chunk017.txt
# Submitted pilot_top_chunk018: 43779872
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_ori.pilot_top_chunk018.txt
# bash: warning: command substitution: ignored null byte in input
# Submitted pilot_top_chunk019: 43779873
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_ori.pilot_top_chunk019.txt
# Submitted pilot_top_chunk020: 43779874
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_ori.pilot_top_chunk020.txt
#
# Submitted pilot_top_chunk001: 43779875
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_dinuc.pilot_top_chunk001.txt
# Submitted pilot_top_chunk002: 43779876
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_dinuc.pilot_top_chunk002.txt
# Submitted pilot_top_chunk003: 43779877
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_dinuc.pilot_top_chunk003.txt
# Submitted pilot_top_chunk004: 43779878
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_dinuc.pilot_top_chunk004.txt
# Submitted pilot_top_chunk005: 43779879
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_dinuc.pilot_top_chunk005.txt
# Submitted pilot_top_chunk006: 43779880
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_dinuc.pilot_top_chunk006.txt
# Submitted pilot_top_chunk007: 43779881
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_dinuc.pilot_top_chunk007.txt
# Submitted pilot_top_chunk008: 43779882
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_dinuc.pilot_top_chunk008.txt
# Submitted pilot_top_chunk009: 43779883
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_dinuc.pilot_top_chunk009.txt
# Submitted pilot_top_chunk010: 43779884
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_dinuc.pilot_top_chunk010.txt
# Submitted pilot_top_chunk011: 43779885
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_dinuc.pilot_top_chunk011.txt
# Submitted pilot_top_chunk012: 43779886
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_dinuc.pilot_top_chunk012.txt
# Submitted pilot_top_chunk013: 43779887
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_dinuc.pilot_top_chunk013.txt
# Submitted pilot_top_chunk014: 43779888
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_dinuc.pilot_top_chunk014.txt
# Submitted pilot_top_chunk015: 43779889
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_dinuc.pilot_top_chunk015.txt
# Submitted pilot_top_chunk016: 43779890
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_dinuc.pilot_top_chunk016.txt
# Submitted pilot_top_chunk017: 43779891
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_dinuc.pilot_top_chunk017.txt
# Submitted pilot_top_chunk018: 43779892
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_dinuc.pilot_top_chunk018.txt
# Submitted pilot_top_chunk019: 43779893
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_dinuc.pilot_top_chunk019.txt
# Submitted pilot_top_chunk020: 43779894
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_dinuc.pilot_top_chunk020.txt
#
# bash: warning: command substitution: ignored null byte in input
# bash: warning: command substitution: ignored null byte in input
# bash: warning: command substitution: ignored null byte in input
# bash: warning: command substitution: ignored null byte in input
# bash: warning: command substitution: ignored null byte in input
# Submitted pilot_low_chunk001: 43779895
# bash: warning: command substitution: ignored null byte in input
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_ori.pilot_low_chunk001.txt
# bash: warning: command substitution: ignored null byte in input
# Submitted pilot_low_chunk002: 43779896
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_ori.pilot_low_chunk002.txt
# Submitted pilot_low_chunk003: 43779897
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_ori.pilot_low_chunk003.txt
# Submitted pilot_low_chunk004: 43779898
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_ori.pilot_low_chunk004.txt
# Submitted pilot_low_chunk005: 43779899
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_ori.pilot_low_chunk005.txt
# Submitted pilot_low_chunk006: 43779900
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_ori.pilot_low_chunk006.txt
# Submitted pilot_low_chunk007: 43779901
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_ori.pilot_low_chunk007.txt
# Submitted pilot_low_chunk008: 43779902
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_ori.pilot_low_chunk008.txt
# Submitted pilot_low_chunk009: 43779903
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_ori.pilot_low_chunk009.txt
# Submitted pilot_low_chunk010: 43779904
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_ori.pilot_low_chunk010.txt
# Submitted pilot_low_chunk011: 43779905
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_ori.pilot_low_chunk011.txt
# Submitted pilot_low_chunk012: 43779906
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_ori.pilot_low_chunk012.txt
# Submitted pilot_low_chunk013: 43779907
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_ori.pilot_low_chunk013.txt
# Submitted pilot_low_chunk014: 43779908
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_ori.pilot_low_chunk014.txt
# Submitted pilot_low_chunk015: 43779909
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_ori.pilot_low_chunk015.txt
# bash: warning: command substitution: ignored null byte in input
# Submitted pilot_low_chunk016: 43779910
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_ori.pilot_low_chunk016.txt
# Submitted pilot_low_chunk017: 43779911
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_ori.pilot_low_chunk017.txt
# Submitted pilot_low_chunk018: 43779912
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_ori.pilot_low_chunk018.txt
# Submitted pilot_low_chunk019: 43779913
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_ori.pilot_low_chunk019.txt
# Submitted pilot_low_chunk020: 43779914
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_ori.pilot_low_chunk020.txt
#
# Submitted pilot_low_chunk001: 43779915
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_dinuc.pilot_low_chunk001.txt
# Submitted pilot_low_chunk002: 43779916
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_dinuc.pilot_low_chunk002.txt
# Submitted pilot_low_chunk003: 43779917
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_dinuc.pilot_low_chunk003.txt
# Submitted pilot_low_chunk004: 43779918
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_dinuc.pilot_low_chunk004.txt
# Submitted pilot_low_chunk005: 43779919
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_dinuc.pilot_low_chunk005.txt
# Submitted pilot_low_chunk006: 43779920
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_dinuc.pilot_low_chunk006.txt
# Submitted pilot_low_chunk007: 43779921
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_dinuc.pilot_low_chunk007.txt
# Submitted pilot_low_chunk008: 43779922
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_dinuc.pilot_low_chunk008.txt
# Submitted pilot_low_chunk009: 43779923
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_dinuc.pilot_low_chunk009.txt
# Submitted pilot_low_chunk010: 43779924
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_dinuc.pilot_low_chunk010.txt
# Submitted pilot_low_chunk011: 43779925
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_dinuc.pilot_low_chunk011.txt
# Submitted pilot_low_chunk012: 43779926
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_dinuc.pilot_low_chunk012.txt
# Submitted pilot_low_chunk013: 43779927
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_dinuc.pilot_low_chunk013.txt
# Submitted pilot_low_chunk014: 43779928
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_dinuc.pilot_low_chunk014.txt
# Submitted pilot_low_chunk015: 43779929
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_dinuc.pilot_low_chunk015.txt
# bash: warning: command substitution: ignored null byte in input
# Submitted pilot_low_chunk016: 43779930
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_dinuc.pilot_low_chunk016.txt
# Submitted pilot_low_chunk017: 43779931
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_dinuc.pilot_low_chunk017.txt
# Submitted pilot_low_chunk018: 43779932
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_dinuc.pilot_low_chunk018.txt
# Submitted pilot_low_chunk019: 43779933
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_dinuc.pilot_low_chunk019.txt
# Submitted pilot_low_chunk020: 43779934
# LOG: ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_dinuc.pilot_low_chunk020.txt

# %% [markdown]
# ## Review

# %%
sacct_summary.sh "${LST_JOBS[@]}"
# Out:
# Detected multiple job IDs (80). Running batch summary.
# ===== Summary (.ba tasks) =====
# JobID             State ExitCode ElapsedRaw   TotalCPU     MaxRSS                       NodeList
# ------------ ---------- -------- ---------- ---------- ---------- ------------------------------
# 43779855.ba+  COMPLETED      0:0         92  00:20.679  19042356K                 dcc-biostat-03
# 43779856.ba+  COMPLETED      0:0         93  00:21.375  19041336K                 dcc-biostat-03
# 43779857.ba+  COMPLETED      0:0         92  00:21.359  19044836K                 dcc-biostat-03
# 43779858.ba+  COMPLETED      0:0         92  00:22.009  19043008K                 dcc-biostat-03
# 43779859.ba+  COMPLETED      0:0         91  00:22.182  19045248K                 dcc-biostat-03
# 43779860.ba+  COMPLETED      0:0         92  00:22.185  19046904K                 dcc-biostat-03
# 43779861.ba+  COMPLETED      0:0         93  00:21.428  19038748K                 dcc-biostat-03
# 43779862.ba+  COMPLETED      0:0         59  00:15.646  13136780K                 dcc-biostat-03
# 43779863.ba+  COMPLETED      0:0         93  00:22.254  19043152K                 dcc-biostat-03
# 43779864.ba+  COMPLETED      0:0         94  00:22.636  19041084K                 dcc-biostat-03
# 43779865.ba+  COMPLETED      0:0         94  00:22.383  19046136K                 dcc-biostat-03
# 43779866.ba+  COMPLETED      0:0         62  00:18.123  13135080K                 dcc-biostat-03
# 43779867.ba+  COMPLETED      0:0         44  00:22.091  19038620K                 dcc-biostat-19
# 43779868.ba+  COMPLETED      0:0         41  00:21.705  19044556K                 dcc-biostat-19
# 43779869.ba+  COMPLETED      0:0         46  00:21.966  19021412K                 dcc-biostat-19
# 43779870.ba+  COMPLETED      0:0        124  01:06.079  19037708K                 dcc-biostat-19
# 43779871.ba+  COMPLETED      0:0        124  01:06.449  19043072K                 dcc-biostat-19
# 43779872.ba+  COMPLETED      0:0        124  01:06.088  19042724K                 dcc-biostat-19
# 43779873.ba+  COMPLETED      0:0        124  01:05.846  15114440K                 dcc-biostat-19
# 43779874.ba+  COMPLETED      0:0        122  01:04.445  16634196K                 dcc-biostat-19
# 43779875.ba+  COMPLETED      0:0        124  01:06.427  19040416K                 dcc-biostat-19
# 43779876.ba+  COMPLETED      0:0        124  01:06.348  16576720K                 dcc-biostat-19
# 43779877.ba+  COMPLETED      0:0        123  01:05.993  19040880K                 dcc-biostat-19
# 43779878.ba+  COMPLETED      0:0        212  00:30.149  19041764K                 dcc-biostat-18
# 43779879.ba+  COMPLETED      0:0        213  00:33.737  19042636K                 dcc-biostat-18
# 43779880.ba+  COMPLETED      0:0        214  00:33.774  19044544K                 dcc-biostat-18
# 43779881.ba+  COMPLETED      0:0        212  00:34.005  19042984K                 dcc-biostat-18
# 43779882.ba+  COMPLETED      0:0        213  00:34.064  19043348K                 dcc-biostat-18
# 43779883.ba+  COMPLETED      0:0        214  00:34.293  19045548K                 dcc-biostat-18
# 43779884.ba+  COMPLETED      0:0        214  00:33.717  19040960K                 dcc-biostat-18
# 43779885.ba+  COMPLETED      0:0        213  00:33.997  19041532K                 dcc-biostat-18
# 43779886.ba+  COMPLETED      0:0        196  00:26.513  19046332K                 dcc-biostat-18
# 43779887.ba+  COMPLETED      0:0        213  00:33.779  19041700K                 dcc-biostat-18
# 43779888.ba+  COMPLETED      0:0        211  00:33.914  19044828K                 dcc-biostat-18
# 43779889.ba+  COMPLETED      0:0        214  00:34.019  19042040K                 dcc-biostat-18
# 43779890.ba+  COMPLETED      0:0        214  00:33.927  19041264K                 dcc-biostat-18
# 43779891.ba+  COMPLETED      0:0        214  00:34.109  19044268K                 dcc-biostat-18
# 43779892.ba+  COMPLETED      0:0        209  00:32.625  19042580K                 dcc-biostat-18
# 43779893.ba+  COMPLETED      0:0         72  00:19.131  13130944K                 dcc-biostat-18
# 43779894.ba+  COMPLETED      0:0        206  00:31.805  19043948K                 dcc-biostat-18
# 43779895.ba+  COMPLETED      0:0        213  00:33.293  19044216K                 dcc-biostat-18
# 43779896.ba+  COMPLETED      0:0        214  00:31.438  19039536K                 dcc-biostat-18
# 43779897.ba+  COMPLETED      0:0         72  00:18.825  13128980K                 dcc-biostat-18
# 43779898.ba+  COMPLETED      0:0        213  00:33.136  19042388K                 dcc-biostat-18
# 43779899.ba+  COMPLETED      0:0        172  00:19.978  19044744K                 dcc-biostat-01
# 43779900.ba+  COMPLETED      0:0        145  00:20.797  19040968K                 dcc-biostat-01
# 43779901.ba+  COMPLETED      0:0        105  00:17.979  13130520K                 dcc-biostat-01
# 43779902.ba+  COMPLETED      0:0        139  00:20.639  19037232K                 dcc-biostat-01
# 43779903.ba+  COMPLETED      0:0        153  00:20.610  19040528K                 dcc-biostat-01
# 43779904.ba+  COMPLETED      0:0        104  00:18.117  13134556K                 dcc-biostat-01
# 43779905.ba+  COMPLETED      0:0        138  00:19.225  19039404K                 dcc-biostat-01
# 43779906.ba+  COMPLETED      0:0        165  00:18.379  19046304K                 dcc-biostat-01
# 43779907.ba+  COMPLETED      0:0        168  00:18.745  19040340K                 dcc-biostat-01
# 43779908.ba+  COMPLETED      0:0        186  00:28.778  19041888K                 dcc-biostat-01
# 43779909.ba+  COMPLETED      0:0        184  00:28.696  19050624K                 dcc-biostat-01
# 43779910.ba+  COMPLETED      0:0        185  00:29.644  19042096K                 dcc-biostat-01
# 43779911.ba+  COMPLETED      0:0        183  00:28.452  19043460K                 dcc-biostat-01
# 43779912.ba+  COMPLETED      0:0        187  00:29.998  19044048K                 dcc-biostat-01
# 43779913.ba+  COMPLETED      0:0        185  00:29.611  19046992K                 dcc-biostat-01
# 43779914.ba+  COMPLETED      0:0        187  00:30.204  19042580K                 dcc-biostat-01
# 43779915.ba+  COMPLETED      0:0        187  00:29.406  19039920K                 dcc-biostat-01
# 43779916.ba+  COMPLETED      0:0        186  00:29.813  19047148K                 dcc-biostat-01
# 43779917.ba+  COMPLETED      0:0        186  00:29.607  19044024K                 dcc-biostat-01
# 43779918.ba+  COMPLETED      0:0        187  00:30.300  19041212K                 dcc-biostat-01
# 43779919.ba+  COMPLETED      0:0         99  00:11.606  13129716K                 dcc-biostat-01
# 43779920.ba+  COMPLETED      0:0         98  00:11.523  13130924K                 dcc-biostat-01
# 43779921.ba+  COMPLETED      0:0        185  00:30.052  19044428K                 dcc-biostat-01
# 43779922.ba+  COMPLETED      0:0        187  00:30.550  19051504K                 dcc-biostat-01
# 43779923.ba+  COMPLETED      0:0        186  00:30.130  19041564K                 dcc-biostat-01
# 43779924.ba+  COMPLETED      0:0        186  00:30.231  19044820K                 dcc-biostat-01
# 43779925.ba+  COMPLETED      0:0        186  00:30.165  19042240K                 dcc-biostat-01
# 43779926.ba+  COMPLETED      0:0         98  00:12.543  13133920K                 dcc-biostat-01
# 43779927.ba+  COMPLETED      0:0         88  00:59.061  15820648K                 dcc-biostat-19
# 43779928.ba+  COMPLETED      0:0         88  00:58.903  17118584K                 dcc-biostat-19
# 43779929.ba+  COMPLETED      0:0         88  00:59.283  19043828K                 dcc-biostat-19
# 43779930.ba+  COMPLETED      0:0         42  00:19.582  19038212K                 dcc-biostat-03
# 43779931.ba+  COMPLETED      0:0         37  00:18.782  19037488K                 dcc-biostat-03
# 43779932.ba+  COMPLETED      0:0        142  00:29.286  19038580K                 dcc-biostat-18
# 43779933.ba+  COMPLETED      0:0        142  00:29.559  19034892K                 dcc-biostat-18
# 43779934.ba+  COMPLETED      0:0         86  00:26.169  19036276K                 dcc-biostat-01
#
# ===== Means over .ba tasks =====
# n=80  mean ElapsedRaw=145.0 sec (2.42 min)  mean MaxRSS=17.36 GiB

# %% [markdown]
# ### Check log files

# %%
cat ${FD_LOG}/run.motifdelta.jvierstra.pilot_top_ori.pilot_top_chunk001.txt
# Out:
# Hostname:           dcc-biostat-03
# Slurm Array Index:  NA
# Time Stamp:         02-26-26+14:50:45
# PWD:                /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/scripts
#
# Loading scan results: /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifscan_pilot_top_ori_jvierstra_v2.1beta/variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk001.npz
# N=5000, M=637, P=79, strands=2
# Load and check in 37.43 seconds
#
# Loading motif Tbind: /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motif_nonredundant_jvierstra_v2.1beta.tbind.pkl
# Loaded Tbind for 637 motifs.
# Load and check in 0.01 seconds
#
# Computing reduced best gain/loss per variant × motif...
# Compute reduced delta + best events in 6.90 seconds
#
# Extracting gain/loss events (one gain + one loss per variant × motif)...
# Summarizing motif-level gain/loss...
# Summarizing variant-level gain/loss...
# Events + summaries in 0.50 seconds
#
# Saving reduced delta NPZ to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot_top_ori_jvierstra_v2.1beta/variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk001.delta.results.npz
# Saving events (gain/loss) to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot_top_ori_jvierstra_v2.1beta/variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk001.delta.event.tsv
# Saving motif summary to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot_top_ori_jvierstra_v2.1beta/variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk001.delta.summary_motif.tsv
# Saving variant summary to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot_top_ori_jvierstra_v2.1beta/variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_top_chunk001.delta.summary_variant.tsv
# Save results in 1.42 seconds
#
# Done.
#
# Done!
# Run Time: 48 seconds

# %%
cat ${FD_LOG}/run.motifdelta.jvierstra.pilot_low_ori.pilot_low_chunk002.txt
# Out:
# Hostname:           dcc-biostat-18
# Slurm Array Index:  NA
# Time Stamp:         02-26-26+14:50:57
# PWD:                /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/scripts
#
# Loading scan results: /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifscan_pilot_low_ori_jvierstra_v2.1beta/variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk002.npz
# N=5000, M=637, P=79, strands=2
# Load and check in 147.65 seconds
#
# Loading motif Tbind: /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motif_nonredundant_jvierstra_v2.1beta.tbind.pkl
# Loaded Tbind for 637 motifs.
# Load and check in 0.01 seconds
#
# Computing reduced best gain/loss per variant × motif...
# Compute reduced delta + best events in 13.17 seconds
#
# Extracting gain/loss events (one gain + one loss per variant × motif)...
# Summarizing motif-level gain/loss...
# Summarizing variant-level gain/loss...
# Events + summaries in 0.32 seconds
#
# Saving reduced delta NPZ to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot_low_ori_jvierstra_v2.1beta/variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk002.delta.results.npz
# Saving events (gain/loss) to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot_low_ori_jvierstra_v2.1beta/variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk002.delta.event.tsv
# Saving motif summary to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot_low_ori_jvierstra_v2.1beta/variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk002.delta.summary_motif.tsv
# Saving variant summary to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot_low_ori_jvierstra_v2.1beta/variant_closed_gof_bluestarr.flankL35R70.unobs_vs_obs.pilot_low_chunk002.delta.summary_variant.tsv
# Save results in 1.33 seconds
#
# Done.
#
# Done!
# Run Time: 2 minutes and 44 seconds

# %% [markdown]
# ### Check output files

# %%
for b in pilot_top pilot_low; do
  for s in ori dinuc; do
    d=${FD_RES}/analysis_variant_motif_richard/motifdelta_${b}_${s}_jvierstra_v2.1beta
    echo "${b}_${s}  events=$(ls -1 ${d}/*.delta.event.tsv | wc -l)  motif=$(ls -1 ${d}/*.delta.summary_motif.tsv | wc -l)  var=$(ls -1 ${d}/*.delta.summary_variant.tsv | wc -l)  npz=$(ls -1 ${d}/*.delta.results.npz | wc -l)"
  done
done
# Out:
# pilot_top_ori  events=21  motif=21  var=21  npz=20
# pilot_top_dinuc  events=21  motif=21  var=21  npz=20
# pilot_low_ori  events=21  motif=21  var=21  npz=20
# pilot_low_dinuc  events=21  motif=21  var=21  npz=20
