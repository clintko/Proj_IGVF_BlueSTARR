# %% [raw]
# ---
# title: Variant results from Richard 01
# subtitle: Explore and get the files
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
source ../run_config_project.sh
show_env
# Out:
# BASE DIRECTORY (FD_BASE):      /hpc/group/igvf/kk319
# REPO DIRECTORY (FD_REPO):      /hpc/group/igvf/kk319/repo
# WORK DIRECTORY (FD_WORK):      /hpc/group/igvf/kk319/work
# DATA DIRECTORY (FD_DATA):      /hpc/group/igvf/kk319/data
# CONTAINER DIR. (FD_SING):      /hpc/group/igvf/kk319/container
#
# You are working with
# PATH OF PROJECT (FD_PRJ):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR
# PROJECT RESULTS (FD_RES):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results
# PROJECT SCRIPTS (FD_EXE):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/scripts
# PROJECT DATA    (FD_DAT):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/data
# PROJECT NOTE    (FD_NBK):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/notebooks
# PROJECT DOCS    (FD_DOC):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/docs
# PROJECT LOG     (FD_LOG):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/log
# PROJECT REF     (FD_REF):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/references
# PROJECT IMAGE   (FP_PRJ_SIF):  /hpc/group/igvf/kk319/container/project/singularity_proj_igvf_bluestarr.sif
# PROJECT CONF.   (FP_CNF):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/scripts/config_project.sh
# PROJECT APP     (FP_APP):      /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/scripts/run_script.sh

# %% [markdown]
# ## Preview

# %%
ls -1 ${FD_RES}
# Out:
# analysis_variant_motif_richard
# analysis_variant_motif_richard_arc251231
# predict_variant_alphagenome
# predict_variant_kircher2019

# %%
ls ${FD_RES}/analysis_variant_motif_richard
# Out:
# background_zero_order.npy
# background_zero_order.tsv
# batches_dev
# batches_pilot
# batches_top
# motifdelta_pilot_jvierstra_v2.1beta
# motifdelta_top_jaspar2024
# motifdelta_top_jvierstra_v2.1beta
# motif_jaspar2024_core_vertebrates_nonredundant.lods.pkl
# motif_jaspar2024_core_vertebrates_nonredundant.pmap.pkl
# motif_jaspar2024_core_vertebrates_nonredundant.tbind.pkl
# motif_nonredundant_jvierstra_v2.1beta.lods.pkl
# motif_nonredundant_jvierstra_v2.1beta.pmap.pkl
# motif_nonredundant_jvierstra_v2.1beta.tbind.pkl
# motifscan_pilot_jvierstra_v2.1beta
# motifscan_top_jaspar2024
# motifscan_top_jvierstra_v2.1beta
# variant_closed_gof_bluestarr.flankL35R70.ref.fa
# variant_closed_gof_bluestarr.tsv

# %%
ls ${FD_RES}/analysis_variant_motif_richard/batches_pilot
# Out:
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk001.ref.fa.gz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk002.ref.fa.gz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk003.ref.fa.gz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk004.ref.fa.gz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk005.ref.fa.gz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk006.ref.fa.gz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk007.ref.fa.gz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk008.ref.fa.gz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk009.ref.fa.gz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk010.ref.fa.gz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk011.ref.fa.gz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk012.ref.fa.gz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk013.ref.fa.gz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk014.ref.fa.gz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk015.ref.fa.gz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk016.ref.fa.gz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk017.ref.fa.gz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk018.ref.fa.gz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk019.ref.fa.gz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk020.ref.fa.gz

# %% [markdown]
# ## Non-redundant motifs

# %% [markdown]
# ### Prepare

# %%
FD_BATCH=${FD_RES}/analysis_variant_motif_richard/batches_pilot
FD_MSCAN=${FD_RES}/analysis_variant_motif_richard/motifscan_pilot_jvierstra_v2.1beta
FD_DELTA=${FD_RES}/analysis_variant_motif_richard/motifdelta_pilot_jvierstra_v2.1beta

FP_MOTIF=${FD_RES}/analysis_variant_motif_richard/motif_nonredundant_jvierstra_v2.1beta.lods.pkl
FP_TBIND=${FD_RES}/analysis_variant_motif_richard/motif_nonredundant_jvierstra_v2.1beta.tbind.pkl

mkdir -p "${FD_MSCAN}"
mkdir -p "${FD_DELTA}"

# %%
ls -1 ${FD_MSCAN}
# Out:
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk001.npz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk002.npz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk003.npz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk004.npz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk005.npz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk006.npz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk007.npz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk008.npz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk009.npz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk010.npz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk011.npz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk012.npz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk013.npz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk014.npz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk015.npz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk016.npz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk017.npz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk018.npz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk019.npz
# variant_closed_gof_bluestarr.flankL35R70.pilot_chunk020.npz

# %% [markdown]
# ### Execute

# %%
### set script
FP_EXE=${FD_EXE}/run_motifdelta_02_delta.sh

### set slurm opt
NUM_CPU=2
NUM_MEM=50G

LST_OPTS=(
    -A majoroslab
    -p igvf,common
    --exclude=dcc-comp-10,dcc-core-08,dcc-core-53
    --cpus-per-task="${NUM_CPU}"
    --mem="${NUM_MEM}"
    --chdir="${FD_EXE}"
    --export=ALL,FP_CNF="${FP_CNF}"
    --parsable
)

### loop init
LST_JOBS=()
FN_PREFIX=variant_closed_gof_bluestarr.flankL35R70

### Loop through I/O
for i in $(seq -w 001 020); do

    ### set I/O
    TXT_TAG="pilot_chunk${i}"
    TXT_JOB="motifdelta.jvierstra.${TXT_TAG}"
    
    FP_INP=${FD_MSCAN}/${FN_PREFIX}.${TXT_TAG}.npz
    FP_OUT_PREFIX=${FD_DELTA}/${FN_PREFIX}.${TXT_TAG}
    FP_LOG=${FD_LOG}/run.${TXT_JOB}.txt
    #FP_LOG=${FD_LOG}/run.motifscan.jaspar.batch.${TXT_TAG}.%j.txt
    
    ### check file existence
    if [[ ! -f "${FP_INP}" ]]; then
        echo "Missing input: ${FP_INP}"
        continue
    fi
    
    ### execute
    JOBID=$(sbatch   \
        "${LST_OPTS[@]}" \
        --job-name="${TXT_JOB}" \
        --output="${FP_LOG}"    \
        "${FP_EXE}" "${FP_INP}" "${FP_TBIND}" "${FP_OUT_PREFIX}"
    )
    echo "Submitted ${TXT_TAG}: ${JOBID}"
    LST_JOBS+=("${JOBID}")
done
# Out:
# Submitted pilot_chunk001: 42226947
# Submitted pilot_chunk002: 42226948
# Submitted pilot_chunk003: 42226949
# Submitted pilot_chunk004: 42226950
# Submitted pilot_chunk005: 42226951
# Submitted pilot_chunk006: 42226952
# Submitted pilot_chunk007: 42226953
# Submitted pilot_chunk008: 42226954
# Submitted pilot_chunk009: 42226955
# Submitted pilot_chunk010: 42226956
# Submitted pilot_chunk011: 42226957
# Submitted pilot_chunk012: 42226958
# Submitted pilot_chunk013: 42226959
# Submitted pilot_chunk014: 42226960
# Submitted pilot_chunk015: 42226961
# Submitted pilot_chunk016: 42226962
# Submitted pilot_chunk017: 42226963
# Submitted pilot_chunk018: 42226966
# Submitted pilot_chunk019: 42226967
# Submitted pilot_chunk020: 42226968

# %% [markdown]
# ## Review

# %%
sacct_summary.sh "${LST_JOBS[@]}"
# Out:
# Detected multiple job IDs (20). Running batch summary.
# ===== Summary (.ba tasks) =====
# JobID             State ExitCode ElapsedRaw   TotalCPU     MaxRSS                       NodeList
# ------------ ---------- -------- ---------- ---------- ---------- ------------------------------
# 42226947.ba+  COMPLETED      0:0        119  01:16.420  17029360K                    dcc-core-43
# 42226948.ba+  COMPLETED      0:0        114  01:15.605  15543844K                    dcc-core-43
# 42226949.ba+  COMPLETED      0:0        116  01:17.279  17798720K                    dcc-core-43
# 42226950.ba+  COMPLETED      0:0        119  01:16.538  17095884K                    dcc-core-43
# 42226951.ba+  COMPLETED      0:0        103  01:08.894  16316560K                    dcc-core-47
# 42226952.ba+  COMPLETED      0:0        106  01:10.168  15403696K                    dcc-core-47
# 42226953.ba+  COMPLETED      0:0        108  01:08.495  17080092K                    dcc-core-47
# 42226954.ba+  COMPLETED      0:0        109  01:08.534  14347388K                    dcc-core-47
# 42226955.ba+  COMPLETED      0:0        168  01:56.931  13383780K                    dcc-core-54
# 42226956.ba+  COMPLETED      0:0        170  01:56.242  19053184K                    dcc-core-54
# 42226957.ba+  COMPLETED      0:0        170  01:55.563  14149328K                    dcc-core-54
# 42226958.ba+  COMPLETED      0:0        169  01:53.192  19059096K                    dcc-core-54
# 42226959.ba+  COMPLETED      0:0        165  01:54.577  14213800K                    dcc-core-54
# 42226960.ba+  COMPLETED      0:0        166  01:56.774  13139140K                    dcc-core-54
# 42226961.ba+  COMPLETED      0:0        171  01:55.204  15009676K                    dcc-core-54
# 42226962.ba+  COMPLETED      0:0        170  01:56.040  19053896K                    dcc-core-54
# 42226963.ba+  COMPLETED      0:0        137  01:51.325  13670708K                    dcc-comp-02
# 42226966.ba+  COMPLETED      0:0        138  01:51.317  19042628K                    dcc-comp-02
# 42226967.ba+  COMPLETED      0:0        139  01:49.543  16118604K                    dcc-comp-02
# 42226968.ba+  COMPLETED      0:0        139  01:50.138  19041780K                    dcc-comp-02
#
# ===== Means over .ba tasks =====
# n=20  mean ElapsedRaw=139.8 sec (2.33 min)  mean MaxRSS=15.52 GiB
# /hpc/group/igvf/kk319/bins/sacct_summary_batch.sh: line 56: 20,State,ExitCode,ElapsedRaw,TotalCPU,MaxRSS,NodeList%30: command not found
#
# ===== Means over .ba tasks =====
# n=20  mean ElapsedRaw=139.8 sec (2.33 min)  mean MaxRSS=15.52 GiB

# %%
cat ${FD_LOG}/run.motifdelta.jvierstra.pilot_chunk001.txt
# Out:
# Hostname:           dcc-core-43
# Slurm Array Index:  NA
# Time Stamp:         01-20-26+03:12:52
# PWD:                /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/scripts
#
# Loading scan results: /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifscan_pilot_jvierstra_v2.1beta/variant_closed_gof_bluestarr.flankL35R70.pilot_chunk001.npz
# N=5000, M=637, P=79, strands=2
# Load and check in 49.43 seconds
#
# Loading motif Tbind: /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motif_nonredundant_jvierstra_v2.1beta.tbind.pkl
# Loaded Tbind for 637 motifs.
# Load and check in 0.01 seconds
#
# Computing reduced best gain/loss per variant × motif...
# Compute reduced delta + best events in 41.38 seconds
#
# Extracting gain/loss events (one gain + one loss per variant × motif)...
# Summarizing motif-level gain/loss...
# Summarizing variant-level gain/loss...
# Events + summaries in 0.55 seconds
#
# Saving reduced delta NPZ to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot_jvierstra_v2.1beta/variant_closed_gof_bluestarr.flankL35R70.pilot_chunk001.delta.results.npz
# Saving events (gain/loss) to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot_jvierstra_v2.1beta/variant_closed_gof_bluestarr.flankL35R70.pilot_chunk001.delta.event.tsv
# Saving motif summary to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot_jvierstra_v2.1beta/variant_closed_gof_bluestarr.flankL35R70.pilot_chunk001.delta.summary_motif.tsv
# Saving variant summary to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot_jvierstra_v2.1beta/variant_closed_gof_bluestarr.flankL35R70.pilot_chunk001.delta.summary_variant.tsv
# Save results in 1.57 seconds
#
# Done.
#
# Done!
# Run Time: 1 minutes and 40 seconds

# %%
cat ${FD_LOG}/run.motifdelta.jvierstra.pilot_chunk020.txt
# Out:
# Hostname:           dcc-comp-02
# Slurm Array Index:  NA
# Time Stamp:         01-20-26+03:12:50
# PWD:                /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/scripts
#
# Loading scan results: /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifscan_pilot_jvierstra_v2.1beta/variant_closed_gof_bluestarr.flankL35R70.pilot_chunk020.npz
# N=5000, M=637, P=79, strands=2
# Load and check in 52.82 seconds
#
# Loading motif Tbind: /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motif_nonredundant_jvierstra_v2.1beta.tbind.pkl
# Loaded Tbind for 637 motifs.
# Load and check in 0.01 seconds
#
# Computing reduced best gain/loss per variant × motif...
# Compute reduced delta + best events in 66.88 seconds
#
# Extracting gain/loss events (one gain + one loss per variant × motif)...
# Summarizing motif-level gain/loss...
# Summarizing variant-level gain/loss...
# Events + summaries in 0.31 seconds
#
# Saving reduced delta NPZ to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot_jvierstra_v2.1beta/variant_closed_gof_bluestarr.flankL35R70.pilot_chunk020.delta.results.npz
# Saving events (gain/loss) to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot_jvierstra_v2.1beta/variant_closed_gof_bluestarr.flankL35R70.pilot_chunk020.delta.event.tsv
# Saving motif summary to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot_jvierstra_v2.1beta/variant_closed_gof_bluestarr.flankL35R70.pilot_chunk020.delta.summary_motif.tsv
# Saving variant summary to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot_jvierstra_v2.1beta/variant_closed_gof_bluestarr.flankL35R70.pilot_chunk020.delta.summary_variant.tsv
# Save results in 0.83 seconds
#
# Done.
#
# Done!
# Run Time: 2 minutes and 3 seconds

# %%
cat ${FD_LOG}/run.motifdelta.jvierstra.pilot_chunk018.txt
# Out:
# Hostname:           dcc-comp-02
# Slurm Array Index:  NA
# Time Stamp:         01-20-26+03:12:50
# PWD:                /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/scripts
#
# Loading scan results: /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifscan_pilot_jvierstra_v2.1beta/variant_closed_gof_bluestarr.flankL35R70.pilot_chunk018.npz
# N=5000, M=637, P=79, strands=2
# Load and check in 51.59 seconds
#
# Loading motif Tbind: /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motif_nonredundant_jvierstra_v2.1beta.tbind.pkl
# Loaded Tbind for 637 motifs.
# Load and check in 0.00 seconds
#
# Computing reduced best gain/loss per variant × motif...
# Compute reduced delta + best events in 67.43 seconds
#
# Extracting gain/loss events (one gain + one loss per variant × motif)...
# Summarizing motif-level gain/loss...
# Summarizing variant-level gain/loss...
# Events + summaries in 0.31 seconds
#
# Saving reduced delta NPZ to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot_jvierstra_v2.1beta/variant_closed_gof_bluestarr.flankL35R70.pilot_chunk018.delta.results.npz
# Saving events (gain/loss) to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot_jvierstra_v2.1beta/variant_closed_gof_bluestarr.flankL35R70.pilot_chunk018.delta.event.tsv
# Saving motif summary to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot_jvierstra_v2.1beta/variant_closed_gof_bluestarr.flankL35R70.pilot_chunk018.delta.summary_motif.tsv
# Saving variant summary to /hpc/group/igvf/kk319/repo/Proj_IGVF_BlueSTARR/results/analysis_variant_motif_richard/motifdelta_pilot_jvierstra_v2.1beta/variant_closed_gof_bluestarr.flankL35R70.pilot_chunk018.delta.summary_variant.tsv
# Save results in 0.91 seconds
#
# Done.
#
# Done!
# Run Time: 2 minutes and 2 seconds
